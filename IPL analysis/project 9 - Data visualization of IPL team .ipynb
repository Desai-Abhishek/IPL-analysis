# %%
#problem statement : create best team for world-cup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
##reading data

# %%
df=pd.read_csv("IPLData.csv")

# %%
df.head()
# Out:
#        Player Name       Team Nationality Player_Type  Capped  Matches_Played  \
# 0   Shikhar Dhawan     Punjab      Indian      Batter       1           192.0
# 1    Shreyas Iyer     Kolkata      Indian      Batter       1            87.0
# 2   Faf Du Plessis  Bangalore    Overseas      Batter       1           100.0
# 3   Manish Pandey     Lucknow      Indian      Batter       1           154.0
# 4  Shimron Hetmyer  Rajasthan    Overseas      Batter       1            31.0
#
#      Runs  Average  Strike_Rate  Wickets  Bowling_average  Economy  \
# 0  5783.0    34.63       126.60      4.0             16.5     8.25
# 1  2375.0    31.67       123.96      NaN              NaN      NaN
# 2  2935.0    34.94       131.09      NaN              NaN      NaN
# 3  3560.0    30.69       121.83      NaN              NaN      NaN
# 4   517.0    25.85       151.17      NaN              NaN      NaN
#
#    Bowling_Strike_Rate  Catches  Run_outs  Stumps
# ...

# %%
df.tail()
# Out:
#          Player Name     Team Nationality Player_Type  Capped  Matches_Played  \
# 230     Ravi Bishnoi  Lucknow      Indian     Bowler        1            23.0
# 231  Ruturaj Gaikwad  Chennai      Indian      Batter       1            22.0
# 232    Sunil Narine   Kolkata    Overseas  Allrounder       1           134.0
# 233  Kieron Pollard    Mumbai    Overseas  Allrounder       1           178.0
# 234    Anrich Nortje    Delhi    Overseas     Bowler        1            24.0
#
#        Runs  Average  Strike_Rate  Wickets  Bowling_average  Economy  \
# 230     8.0     4.00        50.00     24.0            25.25     6.97
# 231   839.0    46.61       132.13      NaN              NaN      NaN
# 232   954.0    15.64       161.69    143.0            24.53     6.74
# 233  3268.0    29.98       149.77     65.0            31.62     8.78
# 234     7.0     7.00       116.67     34.0            20.56     7.65
#
#      Bowling_Strike_Rate  Catches  Run_outs  Stumps
# ...

# %%
 #analyze the data

# %%
df.describe()
# Out:
#            Capped  Matches_Played         Runs     Average  Strike_Rate  \
# count  235.000000      215.000000   165.000000  161.000000   163.000000
# mean     0.838298       43.897674   840.575758   21.792391   121.009939
# std      0.561802       48.695302  1270.341831   11.664156    30.739189
# min      0.000000        1.000000     0.000000    0.000000     0.000000
# 25%      0.500000       11.500000    67.000000   13.800000   112.635000
# 50%      1.000000       25.000000   289.000000   22.410000   128.630000
# 75%      1.000000       56.000000   954.000000   29.300000   137.550000
# max      2.000000      220.000000  6283.000000   58.500000   190.240000
#
#           Wickets  Bowling_average     Economy  Bowling_Strike_Rate  \
# count  140.000000       135.000000  143.000000           119.000000
# mean    31.485714        32.907185    8.223182            24.686134
# std     36.872420        18.191441    1.223541            12.982049
# ...

# %%
df.isnull().sum()
# Out:
# Player Name              0
# Team                     0
# Nationality              0
# Player_Type              0
# Capped                   0
# Matches_Played          20
# Runs                    70
# Average                 74
# Strike_Rate             72
# Wickets                 95
# Bowling_average        100
# Economy                 92
# Bowling_Strike_Rate    116
# Catches                208
# Run_outs               208
# Stumps                 208
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Player Name          235 non-null    object
#  1   Team                 235 non-null    object
#  2   Nationality          235 non-null    object
#  3   Player_Type          235 non-null    object
#  4   Capped               235 non-null    int64
#  5   Matches_Played       215 non-null    float64
#  6   Runs                 165 non-null    float64
#  7   Average              161 non-null    float64
#  8   Strike_Rate          163 non-null    float64
#  9   Wickets              140 non-null    float64
#  10  Bowling_average      135 non-null    float64
#  11  Economy              143 non-null    float64
#  12  Bowling_Strike_Rate  119 non-null    float64
#  13  Catches              27 non-null     float64
#  14  Run_outs             27 non-null     float64
# ...

# %%
# cleaning the data

# %%
## i want only capped data beacause players have relevet experience , so i have to remove to the uncapped data

# %%
df['Player_Type'].unique()
# Out:
# array(['Batter', 'Bowler ', 'Keeper', 'Allrounder'], dtype=object)

# %%
## segregating data - capped batters
## first i find out batters the batters so i consider some important column 

Batter = df[(df['Player_Type']=='Batter') & (df['Capped']==1)]
Batter_new = Batter[['Player Name','Team','Nationality','Matches_Played','Runs','Average','Strike_Rate']]
Batter_new
# Out:
#           Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 0      Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 1       Shreyas Iyer     Kolkata      Indian            87.0  2375.0    31.67
# 2      Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 3      Manish Pandey     Lucknow      Indian           154.0  3560.0    30.69
# 4     Shimron Hetmyer  Rajasthan    Overseas            31.0   517.0    25.85
# 5       Robin Uthappa    Chenai       Indian           193.0  4722.0    27.94
# 6           Jason Roy    Gujarat    Overseas            13.0   329.0    29.91
# 7    Devdutt Padikkal  Rajasthan      Indian            29.0   884.0    31.57
# 8         Priyam Garg  Hyderabad      Indian            19.0   205.0    14.64
# 12     Rahul Tripathi  Hyderabad      Indian            62.0  1385.0    26.13
# 13      Aiden Markram  Hyderabad    Overseas             6.0   146.0    29.30
# ...

# %%
## segregating data - capped bowlers
## i find out the bowlers so i consider some important column 

Bowlers = df[(df['Player_Type']=='Bowler ') & (df['Capped']==1)]
Bowlers_new = Bowlers[['Player Name','Team','Nationality','Matches_Played','Wickets',
                       'Bowling_average', 'Economy', 'Bowling_Strike_Rate']]
Bowlers_new
# Out:
#              Player Name       Team Nationality  Matches_Played  Wickets  \
# 36        Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 37          Trent Boult   Rajasthan    Overseas            62.0     76.0
# 38       Mohammad Shami     Gujarat      Indian            77.0     79.0
# 39           T Natarajan  Hyderabad      Indian            24.0     20.0
# 40        Deepak Chahar     Chennai      Indian            63.0     59.0
# 41      Prasidh Krishna   Rajasthan      Indian            34.0     30.0
# 42       Lockei Ferguson    Gujarat    Overseas            22.0     24.0
# 43       Josh Hazlewood   Bangalore    Overseas            12.0     12.0
# 45     Bhuvneshwar Kumar  Hyderabad      Indian           132.0    142.0
# 46       Shardul Thakur       Delhi      Indian            61.0     67.0
# 47    Mustafizur Rahman       Delhi    Overseas            38.0     38.0
# 48         Kuldeep Yadav      Delhi      Indian            45.0     40.0
# ...

# %%
df.columns
# Out:
# Index(['Player Name', 'Team', 'Nationality', 'Player_Type', 'Capped',
#        'Matches_Played', 'Runs', 'Average', 'Strike_Rate', 'Wickets',
#        'Bowling_average', 'Economy', 'Bowling_Strike_Rate', 'Catches',
#        'Run_outs', 'Stumps'],
#       dtype='object')

# %%
## segregating data - capped keepers
## i find out the Keepers so i consider some important column 

Keeper = df[(df['Player_Type']=='Keeper') & (df['Capped']==1)]
Keeper_new = Keeper[['Player Name','Team','Nationality','Matches_Played','Runs', 'Average',
                     'Strike_Rate','Catches','Run_outs', 'Stumps']]
Keeper_new
# Out:
#            Player Name       Team Nationality  Matches_Played    Runs  \
# 105    Quinton De Kock    Lucknow    Overseas            77.0  2256.0
# 106      Ambati Rayudu    Chennai      Indian           175.0  3916.0
# 107       Ishan Kishan     Mumbai      Indian            61.0  1452.0
# 108     Jonny Bairstow     Punjab    Overseas            28.0  1038.0
# 109     Dinesh Karthik  Bangalore      Indian           213.0  4046.0
# 110   Nicholas Pooran   Hyderabad    Overseas            33.0   606.0
# 111          KS Bharat      Delhi      Indian             8.0   191.0
# 112         Anuj Rawat  Bangalore      Indian             1.0     0.0
# 113  Prabhsimran Singh     Punjab      Indian             5.0    50.0
# 114   Sheldon Jackson     Kolkata    Overseas             4.0    38.0
# 117      Sam Billings     Kolkata    Overseas            22.0   334.0
# 118   Wridhhiman Saha     Gujarat      Indian           133.0  2110.0
# ...

# %%
## segregating data - capped Allrounder
## i find out the Allrounder so i consider some important column 

Allrounder = df[(df['Player_Type']=='Allrounder') & (df['Capped']==1)]
Allrounder_new = Allrounder[['Player Name','Team','Nationality','Matches_Played','Runs', 'Average',
                     'Strike_Rate','Wickets','Bowling_average', 'Economy', 'Bowling_Strike_Rate']]
Allrounder_new
# Out:
#               Player Name       Team Nationality  Matches_Played    Runs  \
# 127  Ravichandran Ashwin   Rajasthan      Indian           167.0   456.0
# 128          Pat Cummins     Kolkata    Overseas            37.0   316.0
# 129         Dwayne Bravo     Chennai    Overseas           151.0  1537.0
# 130          Nitish Rana     Kolkata      Indian            77.0  1820.0
# 131          Jason Holder    Lucknow    Overseas            26.0   189.0
# 132         Harshal Patel  Bangalore      Indian            63.0   187.0
# 133          Deepak Hooda    Lucknow      Indian            80.0   785.0
# 135     Washington Sundar  Hyderabad      Indian            42.0   217.0
# 136         Krunal Pandya    Lucknow      Indian            84.0  1143.0
# 137        Mitchell Marsh      Delhi    Overseas            21.0   225.0
# 138           Riyan Parag  Rajasthan      Indian            30.0   339.0
# 139      Abhishek Sharma   Hyderabad      Indian            22.0   241.0
# ...

# %%
## cleaning the data by making null values to 0

# %%
Batter_new.fillna(0,inplace=True)

Bowlers_new.fillna(0,inplace=True)

Keeper_new.fillna(0,inplace=True)

Allrounder_new.fillna(0,inplace=True)
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\pandas\core\frame.py:5176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
print(Batter_new.isnull().sum())
print()

print(Bowlers_new.isnull().sum())
print()

print(Keeper_new.isnull().sum())
print()

print(Allrounder_new.isnull().sum())
print()
# Out:
# Player Name       0
# Team              0
# Nationality       0
# Matches_Played    0
# Runs              0
# Average           0
# Strike_Rate       0
# dtype: int64
#
# Player Name            0
# Team                   0
# Nationality            0
# Matches_Played         0
# Wickets                0
# Bowling_average        0
# Economy                0
# Bowling_Strike_Rate    0
# dtype: int64
#
# Player Name       0
# Team              0
# Nationality       0
# Matches_Played    0
# Runs              0
# Average           0
# Strike_Rate       0
# Catches           0
# Run_outs          0
# Stumps            0
# dtype: int64
#
# Player Name            0
# Team                   0
# Nationality            0
# Matches_Played         0
# Runs                   0
# Average                0
# Strike_Rate            0
# Wickets                0
# Bowling_average        0
# Economy                0
# Bowling_Strike_Rate    0
# dtype: int64

# %%
## analyzing batters data 
top_batters = Batter_new.loc[Batter_new['Average'] >=32]
top_batters
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 19     David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 26     David Miller     Gujarat    Overseas            89.0  1974.0    32.90
# 207  Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 208      Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 212        KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 231  Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
#
#      Strike_Rate
# 0         126.60
# 2         131.09
# 19        139.97
# 26        136.51
# 207       131.27
# 208       129.95
# 212       136.38
# 231       132.13

# %%
top_batters_avg = top_batters.sort_values('Average' , ascending=False)
top_batters_avg
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 212        KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 231  Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
# 19     David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 207  Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 208      Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 26     David Miller     Gujarat    Overseas            89.0  1974.0    32.90
#
#      Strike_Rate
# 212       136.38
# 231       132.13
# 19        139.97
# 207       131.27
# 208       129.95
# 2         131.09
# 0         126.60
# 26        136.51

# %%
top_batters_matchplayed = top_batters.sort_values('Matches_Played' , ascending=False)
top_batters_matchplayed
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 208      Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 19     David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 212        KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 26     David Miller     Gujarat    Overseas            89.0  1974.0    32.90
# 207  Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 231  Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
#
#      Strike_Rate
# 208       129.95
# 0         126.60
# 19        139.97
# 2         131.09
# 212       136.38
# 26        136.51
# 207       131.27
# 231       132.13

# %%
top_batters_runs= top_batters.sort_values('Runs' , ascending=False)
top_batters_runs
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 208      Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 19     David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 212        KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 26     David Miller     Gujarat    Overseas            89.0  1974.0    32.90
# 207  Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 231  Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
#
#      Strike_Rate
# 208       129.95
# 0         126.60
# 19        139.97
# 212       136.38
# 2         131.09
# 26        136.51
# 207       131.27
# 231       132.13

# %%
top_batters_strikerate=top_batters.sort_values('Strike_Rate' , ascending=False)
top_batters_strikerate
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 19     David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 26     David Miller     Gujarat    Overseas            89.0  1974.0    32.90
# 212        KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 231  Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
# 207  Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 208      Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
#
#      Strike_Rate
# 19        139.97
# 26        136.51
# 212       136.38
# 231       132.13
# 207       131.27
# 2         131.09
# 208       129.95
# 0         126.60

# %%
# Top batsman 
# 1) David Warner
# 2) KL Rahul
# 3) Virat Kohli

# %%
## analyzing bowlers data 
top_bowlers = Bowlers_new.loc[Bowlers_new['Bowling_average'] <=24]
top_bowlers
# Out:
#              Player Name       Team Nationality  Matches_Played  Wickets  \
# 36        Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 50     Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
# 83            Rasikh Dar    Kolkata      Indian             1.0      1.0
# 87           Sean Abbott  Hyderabad    Overseas             2.0      0.0
# 88        Alzarri Joseph    Gujarat    Overseas             3.0      6.0
# 93          Lungi Ngidi      Delhi     Overseas            14.0     25.0
# 101         Kuldip Yadav  Rajasthan      Indian             1.0      0.0
# 103  Nathan Coulter-Nile  Rajasthan    Overseas            38.0     48.0
# 210      Arshdeep Singh      Punjab      Indian            23.0     30.0
# 214   Varun Chakravarthy    Kolkata      Indian            31.0     36.0
# 215       Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# 234        Anrich Nortje      Delhi    Overseas            24.0     34.0
#
# ...

# %%
top_bowlers_avg = top_bowlers.sort_values('Bowling_average')

top_bowlers_Bowling_Strike_Rate = top_bowlers.sort_values('Bowling_Strike_Rate')

top_bowlers_Wickets = top_bowlers.sort_values('Wickets' , ascending=False)

top_bowlers_Economy = top_bowlers.sort_values('Economy')

top_bowlers_Matches_Played = top_bowlers.sort_values('Matches_Played' , ascending=False)

# %%
top_bowlers_avg
# Out:
#              Player Name       Team Nationality  Matches_Played  Wickets  \
# 83            Rasikh Dar    Kolkata      Indian             1.0      1.0
# 87           Sean Abbott  Hyderabad    Overseas             2.0      0.0
# 101         Kuldip Yadav  Rajasthan      Indian             1.0      0.0
# 88        Alzarri Joseph    Gujarat    Overseas             3.0      6.0
# 93          Lungi Ngidi      Delhi     Overseas            14.0     25.0
# 36        Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 234        Anrich Nortje      Delhi    Overseas            24.0     34.0
# 103  Nathan Coulter-Nile  Rajasthan    Overseas            38.0     48.0
# 50     Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
# 210      Arshdeep Singh      Punjab      Indian            23.0     30.0
# 215       Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# 214   Varun Chakravarthy    Kolkata      Indian            31.0     36.0
#
# ...

# %%
top_bowlers_Bowling_Strike_Rate
# Out:
#              Player Name       Team Nationality  Matches_Played  Wickets  \
# 83            Rasikh Dar    Kolkata      Indian             1.0      1.0
# 87           Sean Abbott  Hyderabad    Overseas             2.0      0.0
# 101         Kuldip Yadav  Rajasthan      Indian             1.0      0.0
# 88        Alzarri Joseph    Gujarat    Overseas             3.0      6.0
# 93          Lungi Ngidi      Delhi     Overseas            14.0     25.0
# 36        Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 210      Arshdeep Singh      Punjab      Indian            23.0     30.0
# 234        Anrich Nortje      Delhi    Overseas            24.0     34.0
# 103  Nathan Coulter-Nile  Rajasthan    Overseas            38.0     48.0
# 50     Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
# 215       Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# 214   Varun Chakravarthy    Kolkata      Indian            31.0     36.0
#
# ...

# %%
top_bowlers_Wickets
# Out:
#              Player Name       Team Nationality  Matches_Played  Wickets  \
# 50     Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
# 215       Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# 36        Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 103  Nathan Coulter-Nile  Rajasthan    Overseas            38.0     48.0
# 214   Varun Chakravarthy    Kolkata      Indian            31.0     36.0
# 234        Anrich Nortje      Delhi    Overseas            24.0     34.0
# 210      Arshdeep Singh      Punjab      Indian            23.0     30.0
# 93          Lungi Ngidi      Delhi     Overseas            14.0     25.0
# 88        Alzarri Joseph    Gujarat    Overseas             3.0      6.0
# 83            Rasikh Dar    Kolkata      Indian             1.0      1.0
# 87           Sean Abbott  Hyderabad    Overseas             2.0      0.0
# 101         Kuldip Yadav  Rajasthan      Indian             1.0      0.0
#
# ...

# %%
top_bowlers_Economy
# Out:
#              Player Name       Team Nationality  Matches_Played  Wickets  \
# 214   Varun Chakravarthy    Kolkata      Indian            31.0     36.0
# 215       Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# 103  Nathan Coulter-Nile  Rajasthan    Overseas            38.0     48.0
# 50     Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
# 234        Anrich Nortje      Delhi    Overseas            24.0     34.0
# 101         Kuldip Yadav  Rajasthan      Indian             1.0      0.0
# 36        Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 93          Lungi Ngidi      Delhi     Overseas            14.0     25.0
# 210      Arshdeep Singh      Punjab      Indian            23.0     30.0
# 88        Alzarri Joseph    Gujarat    Overseas             3.0      6.0
# 83            Rasikh Dar    Kolkata      Indian             1.0      1.0
# 87           Sean Abbott  Hyderabad    Overseas             2.0      0.0
#
# ...

# %%
top_bowlers_Matches_Played
# Out:
#              Player Name       Team Nationality  Matches_Played  Wickets  \
# 50     Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
# 215       Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# 36        Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 103  Nathan Coulter-Nile  Rajasthan    Overseas            38.0     48.0
# 214   Varun Chakravarthy    Kolkata      Indian            31.0     36.0
# 234        Anrich Nortje      Delhi    Overseas            24.0     34.0
# 210      Arshdeep Singh      Punjab      Indian            23.0     30.0
# 93          Lungi Ngidi      Delhi     Overseas            14.0     25.0
# 88        Alzarri Joseph    Gujarat    Overseas             3.0      6.0
# 87           Sean Abbott  Hyderabad    Overseas             2.0      0.0
# 83            Rasikh Dar    Kolkata      Indian             1.0      1.0
# 101         Kuldip Yadav  Rajasthan      Indian             1.0      0.0
#
# ...

# %%
# Top bowlers
# 1) Yuzvendra Chahal
# 2) Jasprit Bumrah
# 3) Nathan Coulter-Nile
# 4) Kagiso Rabada

# %%
## analyzing Top All-rounder data 
top_Allrounder = Allrounder_new[Allrounder_new['Strike_Rate']>=140]
top_Allrounder
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
#
# ...

# %%
top_Allrounder_Average = top_Allrounder.sort_values('Average' , ascending=False)
top_Allrounder_Runs = top_Allrounder.sort_values('Runs' , ascending=False)
top_Allrounder_Strike_Rate = top_Allrounder.sort_values('Strike_Rate' , ascending=False)
top_Allrounder_Bowling_average = top_Allrounder.sort_values('Bowling_average' )
top_Allrounder_Economy = top_Allrounder.sort_values('Economy' )
top_Allrounder_Bowling_Strike_Rate = top_Allrounder.sort_values('Bowling_Strike_Rate' )
top_Allrounder_Wickets = top_Allrounder.sort_values('Wickets' , ascending=False)
top_Allrounder_Matches_Played = top_Allrounder.sort_values('Matches_Played' , ascending=False)

# %%
top_Allrounder_Average
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
#
# ...

# %%
top_Allrounder_Runs
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
#
# ...

# %%
top_Allrounder_Strike_Rate
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
#
# ...

# %%
top_Allrounder_Bowling_average
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
#
# ...

# %%
top_Allrounder_Economy
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
#
# ...

# %%
top_Allrounder_Bowling_Strike_Rate
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
#
# ...

# %%
top_Allrounder_Wickets
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
#
# ...

# %%
top_Allrounder_Matches_Played
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
#
# ...

# %%
# top all rounders 
# 1) Sunil Narine
# 2) Hardik Pandya
# 3) Andre Russell
# 4) Jofra Archer

# %%
## analyzing top keepers 
top_Keeper = Keeper_new[Keeper_new['Average']>=25]
top_Keeper
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 105       130.90     53.0       0.0    14.0
# ...

# %%
top_Keeper_Matches_Played = top_Keeper.sort_values('Matches_Played' ,  ascending=False )
top_Keeper_Runs = top_Keeper.sort_values('Runs' ,  ascending=False )
top_Keeper_Average = top_Keeper.sort_values('Average' ,  ascending=False )
top_Keeper_Strike_Rate = top_Keeper.sort_values('Strike_Rate' ,  ascending=False )
top_Keeper_Catches = top_Keeper.sort_values('Catches' ,  ascending=False )
top_Keeper_Run_outs = top_Keeper.sort_values('Run_outs' ,  ascending=False )
top_Keeper_Stumps = top_Keeper.sort_values('Stumps' ,  ascending=False )

# %%
top_Keeper_Matches_Played
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# ...

# %%
top_Keeper_Runs
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# ...

# %%
top_Keeper_Average
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 108       142.20     18.0       1.0     4.0
# ...

# %%
top_Keeper_Strike_Rate
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 219       150.00     34.0       3.0     1.0
# ...

# %%
top_Keeper_Catches
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# ...

# %%
top_Keeper_Run_outs
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# ...

# %%
top_Keeper_Stumps
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# ...

# %%
# Top keepers 
# 1) MS Dhoni
# 2) Dinesh Karthik
# 3) Rishabh Pant

# %%
#visulazation of data

# %%
#visulazation of  batters data
#the plot shows each of the top batters strike rate
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Strike_Rate',data=top_batters , order=top_batters.sort_values('Strike_Rate')['Player Name'])
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Strike_Rate'>

# %%
##plot the runs by players 
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Runs',data=top_batters , order=top_batters.sort_values('Runs')['Player Name'])
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Runs'>

# %%
## average by players 
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Average',data=top_batters , order=top_batters.sort_values('Average')['Player Name'])
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Average'>

# %%
#visulazation of bowlwers data 
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Bowling_average',data=top_bowlers , order=top_bowlers.sort_values('Bowling_average')['Player Name'])
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Bowling_average'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Bowling_Strike_Rate',data=top_bowlers , order=top_bowlers.sort_values('Bowling_Strike_Rate')['Player Name'])
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Bowling_Strike_Rate'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Wickets',data=top_bowlers , order=top_bowlers.sort_values('Wickets')['Player Name'])
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Wickets'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Economy',data=top_bowlers , order=top_bowlers.sort_values('Economy')['Player Name'])
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Economy'>

# %%
##visulazation of all rounders data 
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Average',data=top_Allrounder , order=top_Allrounder.sort_values('Average')['Player Name'])
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Average'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Runs',data=top_Allrounder , order=top_Allrounder.sort_values('Runs')['Player Name'])
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Runs'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Strike_Rate',data=top_Allrounder , order=top_Allrounder.sort_values('Strike_Rate')['Player Name'])
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Strike_Rate'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Bowling_average',data=top_Allrounder , order=top_Allrounder.sort_values('Bowling_average')['Player Name'])
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Bowling_average'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Economy',data=top_Allrounder , order=top_Allrounder.sort_values('Economy')['Player Name'])
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Economy'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Bowling_Strike_Rate',data=top_Allrounder , order=top_Allrounder.sort_values('Bowling_Strike_Rate')['Player Name'])
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Bowling_Strike_Rate'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Wickets',data=top_Allrounder , order=top_Allrounder.sort_values('Wickets')['Player Name'])
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Wickets'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Matches_Played',data=top_Allrounder , order=top_Allrounder.sort_values('Matches_Played')['Player Name'])
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Matches_Played'>

# %%
## analyzing the keepers data

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Matches_Played',data=top_Keeper , order=top_Keeper.sort_values('Matches_Played')['Player Name'])
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Matches_Played'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Runs',data=top_Keeper , order=top_Keeper.sort_values('Runs')['Player Name'])
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Runs'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Average',data=top_Keeper , order=top_Keeper.sort_values('Average')['Player Name'])
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Average'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Strike_Rate',data=top_Keeper , order=top_Keeper.sort_values('Strike_Rate')['Player Name'])
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Strike_Rate'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Catches',data=top_Keeper , order=top_Keeper.sort_values('Catches')['Player Name'])
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Catches'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Run_outs',data=top_Keeper , order=top_Keeper.sort_values('Run_outs')['Player Name'])
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Run_outs'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Stumps',data=top_Keeper , order=top_Keeper.sort_values('Stumps')['Player Name'])
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Stumps'>

# %%
#Batters for the Final 11 KL Rahul, Virat Kohli, David Warner 
# we are storing the values of each player in a separate dataframe to use for displaying using the barplot.

matches_values=[top_batters.iloc[6]['Matches_Played'], top_batters.iloc[2]['Matches_Played' ], top_batters.iloc[5]['Matches_Played']]
runs_values=[top_batters.iloc[6]['Runs'], top_batters.iloc[2]['Runs'],top_batters.iloc[5]['Runs']] 
average_values= [top_batters.iloc[6]['Average'], top_batters.iloc[2]['Average'],top_batters.iloc[5]['Average']]
Strike_rate_values= [top_batters.iloc[6]['Strike_Rate'], top_batters.iloc[2]['Strike_Rate'], top_batters.iloc[5]['Strike_Rate']]
                                                                                                                   
Labels=['KL Rahul', 'David Warner', 'Virat Kohli']

fig, axes = plt.subplots(2,2, figsize=(15,10)) 

axes[0][0].set_title("Matches Played")
axes[0][1].set_title("Runs in the IPL Career")
axes[1][0].set_title("Strike Rate")
axes[1][1].set_title("Average")

sns.barplot (x=Labels, y=matches_values, ax=axes[0][0]) 
sns.barplot(x=Labels, y=runs_values, ax=axes[0][1])
sns.barplot(x=Labels, y=Strike_rate_values, ax=axes[1][0])
sns.barplot(x=Labels, y=average_values , ax=axes[1][1])
# Out:
# <AxesSubplot:title={'center':'Average'}>

# %%
## top 11 # top all rounders 
# 1) Sunil Narine
# 2) Hardik Pandya
# 3) Andre Russell

# %%
matches_values=[top_Allrounder.iloc[5]['Matches_Played'], top_Allrounder.iloc[9]['Matches_Played' ], top_Allrounder.iloc[6]['Matches_Played']]
runs_values=[top_Allrounder.iloc[5]['Runs'], top_Allrounder.iloc[9]['Runs'],top_Allrounder.iloc[6]['Runs']] 
average_values= [top_Allrounder.iloc[5]['Average'], top_Allrounder.iloc[9]['Average'],top_Allrounder.iloc[6]['Average']]
Strike_rate_values= [top_Allrounder.iloc[5]['Strike_Rate'], top_Allrounder.iloc[9]['Strike_Rate'], top_Allrounder.iloc[6]['Strike_Rate']]
bowling_Strike_rate_values= [top_Allrounder.iloc[5]['Bowling_Strike_Rate'], top_Allrounder.iloc[9]['Bowling_Strike_Rate'],top_Allrounder.iloc[6]['Bowling_Strike_Rate']]
Bowling_average_values= [top_Allrounder.iloc[5]['Bowling_average'], top_Allrounder.iloc[9]['Bowling_average'],top_Allrounder.iloc[6]['Bowling_average']]
Economy_values= [top_Allrounder.iloc[5]['Economy'], top_Allrounder.iloc[9]['Economy'],top_Allrounder.iloc[6]['Economy']]
Wickets_values= [top_Allrounder.iloc[5]['Wickets'], top_Allrounder.iloc[9]['Wickets'],top_Allrounder.iloc[6]['Wickets']]
                                                                                                                   
Labels=['Andre Russell', 'Sunil Narine', 'Hardik Pandya']

fig, axes = plt.subplots(4,2, figsize=(15,15)) 

axes[0][0].set_title("Matches Played")
axes[0][1].set_title("Runs in the IPL Career")
axes[1][0].set_title("Strike Rate")
axes[1][1].set_title("Average")
axes[2][0].set_title("Bowling_Strike_Rate")
axes[2][1].set_title("Bowling_average")
axes[3][0].set_title("Economy")
axes[3][1].set_title("Wickets")

sns.barplot(x=Labels, y=matches_values, ax=axes[0][0]) 
sns.barplot(x=Labels, y=runs_values, ax=axes[0][1])
sns.barplot(x=Labels, y=Strike_rate_values, ax=axes[1][0])
sns.barplot(x=Labels, y=average_values , ax=axes[1][1])
sns.barplot(x=Labels, y=bowling_Strike_rate_values , ax=axes[2][0])
sns.barplot(x=Labels, y=Bowling_average_values , ax=axes[2][1])
sns.barplot(x=Labels, y=Economy_values , ax=axes[3][0])
sns.barplot(x=Labels, y=Wickets_values , ax=axes[3][1])
# Out:
# <AxesSubplot:title={'center':'Wickets'}>

# %%
## top bowlers for 11 
# 1) Yuzvendra Chahal
# 2) Jasprit Bumrah
# 3) Nathan Coulter-Nile
# 4) Kagiso Rabada

# %%
matches_values=[top_bowlers.iloc[10]['Matches_Played'], top_bowlers.iloc[0]['Matches_Played' ], top_bowlers.iloc[7]['Matches_Played'],top_bowlers.iloc[1]['Matches_Played']]
bowling_Strike_rate_values= [top_bowlers.iloc[10]['Bowling_Strike_Rate'], top_bowlers.iloc[0]['Bowling_Strike_Rate'],top_bowlers.iloc[7]['Bowling_Strike_Rate'],top_bowlers.iloc[1]['Bowling_Strike_Rate']]
Bowling_average_values= [top_bowlers.iloc[10]['Bowling_average'], top_bowlers.iloc[0]['Bowling_average'],top_bowlers.iloc[7]['Bowling_average'],top_bowlers.iloc[1]['Bowling_average']]
Economy_values= [top_bowlers.iloc[10]['Economy'], top_bowlers.iloc[0]['Economy'],top_bowlers.iloc[7]['Economy'],top_bowlers.iloc[1]['Economy']]
Wickets_values= [top_bowlers.iloc[10]['Wickets'], top_bowlers.iloc[0]['Wickets'],top_bowlers.iloc[7]['Wickets'],top_bowlers.iloc[1]['Wickets']]
                                                                                                                   
Labels=['Jasprit Bumrah', 'Kagiso Rabada', 'Nathan Coulter-Nile','Yuzvendra Chahal']

fig, axes = plt.subplots(3,2, figsize=(15,15)) 

axes[0][0].set_title("Matches Played")
axes[0][1].set_title("Bowling_Strike_Rate")
axes[1][0].set_title("Bowling_average")
axes[1][1].set_title("Economy")
axes[2][0].set_title("Wickets")

sns.barplot(x=Labels, y=matches_values, ax=axes[0][0]) 
sns.barplot(x=Labels, y=bowling_Strike_rate_values , ax=axes[0][1])
sns.barplot(x=Labels, y=Bowling_average_values , ax=axes[1][0])
sns.barplot(x=Labels, y=Economy_values , ax=axes[1][1])
sns.barplot(x=Labels, y=Wickets_values , ax=axes[2][0])
# Out:
# <AxesSubplot:title={'center':'Wickets'}>

# %%
### Top keepers 
# 1) MS Dhoni

# %%
matches_values=[top_Keeper.iloc[8]['Matches_Played'], top_Keeper.iloc[8]['Runs']]
average_values=[top_Keeper.iloc[8]['Average'], top_Keeper.iloc[8]['Strike_Rate']]
keeping_values=[top_Keeper.iloc[8]['Catches'], top_Keeper.iloc[8]['Stumps'],top_Keeper.iloc[8]['Run_outs']]

l1=['matches','runs']
l2=['Average','Strike_Rate']
l3=['Catches','Stumps','Run_outs']

fig, axes = plt.subplots(1,3, figsize=(20,10)) 

axes[0].set_title("Matches & runs")
axes[1].set_title("'Average & Strike_Rate")
axes[2].set_title("'Catches , Stumps & Run_outs")


sns.barplot(x=l1, y=matches_values, ax=axes[0]) 
sns.barplot(x=l2, y=average_values, ax=axes[1]) 
sns.barplot(x=l3, y=keeping_values, ax=axes[2])
# Out:
# <AxesSubplot:title={'center':"'Catches , Stumps & Run_outs"}>

# %%
batter1 = top_batters[top_batters['Player Name']=='David Warner ']
batter2 = top_batters[top_batters['Player Name']=='KL Rahul ']
batter3 = top_batters[top_batters['Player Name']=='Virat Kohli']

bowler1 = top_bowlers[top_bowlers['Player Name']=='Jasprit Bumrah']
bowler2 = top_bowlers[top_bowlers['Player Name']=='Kagiso Rabada ']
bowler3 = top_bowlers[top_bowlers['Player Name']=='Nathan Coulter-Nile']
bowler4 = top_bowlers[top_bowlers['Player Name']=='Yuzvendra Chahal ']

allrounder1= top_Allrounder[top_Allrounder['Player Name']=='Sunil Narine ']
allrounder2= top_Allrounder[top_Allrounder['Player Name']=='Hardik Pandya']
allrounder3= top_Allrounder[top_Allrounder['Player Name']=='Andre Russell']

kepper = top_Keeper[top_Keeper['Player Name']=='MS Dhoni']

# %%
final= [batter1,batter2,batter3,bowler1,bowler2,bowler3,bowler4,allrounder1,allrounder2,allrounder3,kepper]
final_team = pd.concat(final)

# %%
final_team_11 = final_team[['Player Name','Team','Nationality']].reset_index()

# %%
final_team_11[['Player Name','Team','Nationality']]
# Out:
#             Player Name       Team Nationality
# 0         David Warner       Delhi    Overseas
# 1             KL Rahul     Lucknow      Indian
# 2           Virat Kohli  Bangalore      Indian
# 3        Jasprit Bumrah     Mumbai      Indian
# 4        Kagiso Rabada      Punjab    Overseas
# 5   Nathan Coulter-Nile  Rajasthan    Overseas
# 6     Yuzvendra Chahal   Rajasthan      Indian
# 7         Sunil Narine     Kolkata    Overseas
# 8         Hardik Pandya    Gujarat      Indian
# 9         Andre Russell    Kolkata    Overseas
# 10             MS Dhoni    Chennai      Indian
